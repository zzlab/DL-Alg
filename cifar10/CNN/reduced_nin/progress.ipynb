# %%
import matplotlib.pylab as pl
# %matplotlib inline
import cPickle as pickle

# %%
test_accuracy, progress = pickle.load(open('history/reduced_nin', 'rb'))

# %%
epoch = progress.pop('epoch')
del progress['validation_accuracy'][0]

# %%
for key, value in progress.items():
    pl.figure()
    pl.grid()
    pl.title(key.replace('_', ' '))
    pl.plot(range(epoch + 1), value)
