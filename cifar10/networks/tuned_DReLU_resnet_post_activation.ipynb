# %%
import numpy as np
import matplotlib.pylab as pl
# %matplotlib inline
import cPickle as pickle

# %%
prefix = 'tuned-resnet-statistics'
path = 'models/%s-post-activations' % prefix
activations = pickle.load(open(path, 'rb'))

# %%
INDEX = 0
for phase in 'test', :
    for index, activation in enumerate(activations[phase]):
        pl.figure()
        print len(np.swapaxes(activation, 0, 1)[INDEX].flatten())
        pl.hist(
            np.swapaxes(activation, 0, 1)[INDEX].flatten(),
            bins   = 256,
            normed = True,
            label  = '%s convolution layer %d filter %d' % (phase, index, INDEX)
        )
        pl.legend(framealpha=0)
# Out:
# 10240000
# 10240000
# 10240000
# 10240000
# 10240000
# 10240000
# 10240000
# 2560000
# 2560000
# 2560000
# 2560000
# 2560000
# 2560000
# 640000
# 640000
# 640000
# 640000
# 640000
# 640000

# %%
import sys
sys.path.append('../../nn')
import MXModels.ResidualNetwork
parameter_path = 'models/%s-parameter' % prefix
_, parameters, states = pickle.load(open(parameter_path))

# %%
for layer in range(15):
    pl.figure()
    pl.title('layer %d' % layer)
    pl.hist(parameters['BNDReLU%d_lower' % layer].asnumpy().flatten(), bins=20, label='lower')
    pl.hist(parameters['BNDReLU%d_upper' % layer].asnumpy().flatten(), bins=20, label='upper')

# %%
for layer in range(15):
    pl.figure()
    pl.hist(parameters['batchnorm%d_beta' % layer].asnumpy(), bins=10)

# %%
for layer in range(15):
    pl.figure()
    pl.hist(states['batchnorm%d_moving_mean' % layer].asnumpy(), bins=10, label='layer %d' % layer)
    pl.legend()
