# %%
import matplotlib.pylab as pl
# %matplotlib inline
import cPickle as pickle

# %%
path = 'whitened-cifar'

# %%
batch = pickle.load(open('%s/test' % path, 'rb'))

# %%
X = batch['data']

# %%
pl.imshow(X[5].reshape((32, 32, 3)))

# %%
from data_utility import load_cifar10

# %%
X, _, _, _, _, _ = load_cifar10(center=True, rescale=True, reshape=True)

# %%
import numpy as np

# %%
gray_X = X.mean(axis=1)

# %%
pl.imshow(gray_X[5])
